# %% [markdown]
# # Libraries

# %% [markdown]
# Import and install necessary libraries

# %%
# !pip install opencv-python==4.7.0.72
# !apt update
# !apt install ffmpeg libsm6 libxext6 -y
# !pip install opencv-python
# !pip install --upgrade pip
# !pip install albumentations==1.3.0
import os
# Out:
# Requirement already satisfied: opencv-python==4.7.0.72 in /root/venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from opencv-python==4.7.0.72) (1.23.4)
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://deb.debian.org/debian-security buster/updates InRelease
# Hit:3 http://deb.debian.org/debian buster-updates InRelease
#
#
#
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
#
#
#
# libsm6 is already the newest version (2:1.2.3-1).
# libxext6 is already the newest version (2:1.3.3-1+b2).
# ffmpeg is already the newest version (7:4.1.10-0+deb10u1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# Requirement already satisfied: opencv-python in /root/venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from opencv-python) (1.23.4)
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (23.0.1)
# Requirement already satisfied: albumentations==1.3.0 in /root/venv/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: PyYAML in /root/venv/lib/python3.9/site-packages (from albumentations==1.3.0) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in /root/venv/lib/python3.9/site-packages (from albumentations==1.3.0) (0.0.4)
# Requirement already satisfied: numpy>=1.11.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from albumentations==1.3.0) (1.23.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /root/venv/lib/python3.9/site-packages (from albumentations==1.3.0) (0.20.0)
# Requirement already satisfied: scipy in /root/venv/lib/python3.9/site-packages (from albumentations==1.3.0) (1.9.1)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /root/venv/lib/python3.9/site-packages (from albumentations==1.3.0) (4.7.0.72)
# Requirement already satisfied: scikit-learn>=0.19.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from qudida>=0.0.4->albumentations==1.3.0) (1.1.2)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from qudida>=0.0.4->albumentations==1.3.0) (4.4.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /root/venv/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2023.3.21)
# Requirement already satisfied: lazy_loader>=0.1 in /root/venv/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (0.2)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in /root/venv/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2.26.1)
# Requirement already satisfied: pillow>=9.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (9.2.0)
# Requirement already satisfied: networkx>=2.8 in /root/venv/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /root/venv/lib/python3.9/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (1.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->scikit-image>=0.16.1->albumentations==1.3.0) (3.0.9)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (3.1.0)

# %% [markdown]
# # Load dataset

# %% [markdown]
# Integrate google drive folder containing data set to notebook

# %%
# !ls /datasets/data/ASL_data/sign_vid/
# Out:
# Admire	Afraid	Angry  Annoy  Bad  Beautiful  Bored  Calm  care  Comfortable

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# At this stage, the dataset undergoes some pre-processing steps.

# %% [markdown]
# Create Frames: After successfully loading data set, write a function to load video data and convert data to picture frames and save frames into a new folder.

# %% [markdown]
# Labelling: After creating frames, the frames are labelled accordingly

# %%
import cv2 
import os

def saving_video_frames(video_dir):
    count = 0
    for vid_folder in os.listdir(video_dir):
        vid_folder_paths = os.path.join(video_dir, vid_folder)
        for video in os.listdir(vid_folder_paths):
            vid_path = os.path.join(vid_folder_paths, video)
            cap = cv2.VideoCapture(vid_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if ret == False:
                    break
                if not os.path.exists(os.path.join('/datasets/data/ASL_data/vid_frame', vid_folder)):
                    os.makedirs(os.path.join('/datasets/data/ASL_data/vid_frame', vid_folder))
                cv2.imwrite(os.path.join(os.path.join('/datasets/data/ASL_data/vid_frame', vid_folder), 'frame'+str(count)+'.jpg'), frame)
                count += 1




testing = saving_video_frames('/datasets/data/ASL_data/sign_vid')
testing
# Out:
# [h264 @ 0x563db409de00] Invalid NAL unit size (745 > 472).
# [h264 @ 0x563db409de00] Error splitting the input into NAL units.

# %% [markdown]
# # Create Model

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=38a13b2f-8e0c-478a-8dcd-2964e3fbb39f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
